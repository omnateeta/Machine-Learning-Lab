# %% [markdown]
# <a href="https://colab.research.google.com/github/omnateeta/Machine-Learning-Lab/blob/main/UntitledML7a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as alt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
data1 = "/content/sample_data/BostonHousing.csv"
data=pd.read_csv(data1)

# %%
print(data.head())
x=data.drop(columns=["medv"])
y=data["medv"]
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
x_train,x_test,y_train, y_test=train_test_split(x,y,test_size=0.2,random_state=420)

# %%
# Check for missing values in x_train
print("Missing values before imputation:")
print(x_train.isnull().sum())

# Impute missing values with the mean of each column
x_train.fillna(x_train.mean(), inplace=True)
x_test.fillna(x_test.mean(), inplace=True)

print("\nMissing values after imputation:")
print(x_train.isnull().sum())
# Out:
# Missing values before imputation:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         5
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# dtype: int64
#
# Missing values after imputation:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# dtype: int64

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
mse=mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
print(f"Mean Squared Error: {mse}")
print(f"R_squared score: {r2}")
# Out:
# Mean Squared Error: 15.391888526618093
# R_squared score: 0.8200223529178464

# %%
alt.figure(figsize=(8,6))
alt.scatter(y_test,y_pred,alpha=0.5,label="Actual vs predicted")
alt.plot([min(y_test),max(y_test)],[min(y_test),max(y_test)],color='red',linestyle='--',label="Ideal Fit Line")
alt.xlabel("Actual Prices")
alt.ylabel("Predicted prices")
alt.title("Actual vs Predicted Prices with Fit Line")
alt.legend()
alt.show()
